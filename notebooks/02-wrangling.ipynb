# %%
import os
import re
import pandas as pd
import json
from pathlib import Path

# %%
data_dir = Path("../data/monthly_data.json")

# %%
with data_dir.open("r", encoding= "utf-8") as file:
    data = json.load(file)

# %%
rows = []

for month, raw in data.items():
    response_data = raw["response"]

    row = {
        "month": month,
        "applied": response_data["applied_total"]["applicants"]["value"],
        "matched": response_data["matched_total"]["applicants"]["value"],
        "accepted": response_data["an_accepted_total"]["applicants"]["value"],
        "approved": response_data["approved_total"]["applicants"]["value"],
        "realized": response_data["realized_total"]["applicants"]["value"],
        "completed": response_data["completed_total"]["applicants"]["value"],
    }
    rows.append(row)

# %%
monthly_data = pd.DataFrame(rows)
monthly_data["month"] = pd.to_datetime(monthly_data["month"])
monthly_data.sort_values("month")
monthly_data
# Out:
#         month  applied  matched  accepted  approved  realized  completed
# 0  2022-01-01        8        2         1         0         0          0
# 1  2022-02-01       11        1         0         0         0          0
# 2  2022-03-01       52       16         7         3         0          0
# 3  2022-04-01       89       13         4         2         0          0
# 4  2022-05-01      132       54        27        20         2          0
# 5  2022-06-01       78       38        22        22         4          0
# 6  2022-07-01       63       18        13         6        35          1
# 7  2022-08-01       39        7         6         6         6          5
# 8  2022-09-01       29       15         4         2         5          2
# 9  2022-10-01       49       21         9         2         4          2
# 10 2022-11-01       36        8         6         6         1          0
# 11 2022-12-01       44        5         3         2         0          0
# 12 2023-01-01       47        9         3         3         1          0
# 13 2023-02-01       44        7         2         0         3          0
# 14 2023-03-01       63       30        14         6         2          1
# 15 2023-04-01       65       27        15         7         2          0
# 16 2023-05-01       82       45        14         8         4          0
# 17 2023-06-01      105       34        13        13         4          3
# 18 2023-07-01       71       41        12         7        11          0
# 19 2023-08-01       69       16         7         4        13          2
# 20 2023-09-01       77       20         6         4         5          3
# 21 2023-10-01       27       10         5         3         6          0
# 22 2023-11-01      105       28        12         4         4          3
# 23 2023-12-01       46       32        17        10         4          0
# 24 2024-01-01       54       20        10        14        13          0
# 25 2024-02-01       39       20         5         8        11          1
# 26 2024-03-01       59       17         1         1         5          0
# 27 2024-04-01       62       29         4         4         0          2
# 28 2024-05-01       75       31        16         6         0          0
# 29 2024-06-01       41       13         5         3         3          0
# 30 2024-07-01       12        0         0         0         5          0
# 31 2024-08-01        6        0         0         0         0          1
# 32 2024-09-01       10        0         0         0         0          1
# 33 2024-10-01        7        1         0         0         4          0
# 34 2024-11-01        4        0         0         0         0          1
# 35 2024-12-01        8        0         0         1         0          0
# 36 2025-01-01       15        3         2         0         1          0
# 37 2025-02-01       14        7         5         3         0          0
# 38 2025-03-01       19        4         2         4         1          0
# 39 2025-04-01       34       17         3         2         1          0
# 40 2025-05-01       30       14         4         3         1          0
# 41 2025-06-01       26        9         5         3         2          0
# 42 2025-07-01       21        7         5         2         3          0
# 43 2025-08-01       29        5         3         3         4          2
# 44 2025-09-01       22       10         4         3         4          0
# 45 2025-10-01       25       13         6         4         6          1
# 46 2025-11-01       34       27         6         2         0          1
# 47 2025-12-01       64       27        21        14         0          0

# %%
output_path = Path("../data/monthly_data.csv")
monthly_data.to_csv(output_path, index= False)
